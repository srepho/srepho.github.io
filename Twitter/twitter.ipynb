# %% [markdown]
# # Twitter Scraping and Analysis.

# %% [raw]
# One of the growing fields in marketing is the usage and monitoring of social media. This post will look at scraping data from Twitter and analysing it. The code is adapted from the excellent "Mining the Social Web" by Matthew A. Russell.

# %% [raw]
# So we are interested in having a look at the twitter usage of a particular account. For this I will use my current employer PGi an audio and web conferencing company. The twitter feed is run out of the US office. Lets start by

# %%
#Authorisation

import json
import twitter

def oauth_login():
    # XXX: Go to http://twitter.com/apps/new to create an app and get values
    # for these credentials that you'll need to provide in place of these
    # empty string values that are defined as placeholders.
    # See https://dev.twitter.com/docs/auth/oauth for more information 
    # on Twitter's OAuth implementation.
    
    CONSUMER_KEY = 'HvMJDVAHiBP1uGpVt2c0Q'
    CONSUMER_SECRET = 'Jwlqespuwd6YqUU7wSHSxZV4kbwLDjedT1uPUTfaFlA'
    OAUTH_TOKEN = '127159325-inpQIxxEgYipUfORCYxpamKo2BRemgfqE4QbjNin'
    OAUTH_TOKEN_SECRET = 'vGkLo8xN6YqNtuNofQnK6lHUpIhYc0AMAOYTqugrHDC0F'
    
    auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                               CONSUMER_KEY, CONSUMER_SECRET)
    
    twitter_api = twitter.Twitter(auth=auth)
    return twitter_api

# Sample usage
twitter_api = oauth_login()    

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print twitter_api
# Out:
# <twitter.api.Twitter object at 0x000000000951AF98>

# %%
#Robust Access 

import sys
import time
from urllib2 import URLError
from httplib import BadStatusLine
import json
import twitter

def make_twitter_request(twitter_api_func, max_errors=10, *args, **kw): 
    
    # A nested helper function that handles common HTTPErrors. Return an updated
    # value for wait_period if the problem is a 500 level error. Block until the
    # rate limit is reset if it's a rate limiting issue (429 error). Returns None
    # for 401 and 404 errors, which requires special handling by the caller.
    def handle_twitter_http_error(e, wait_period=2, sleep_when_rate_limited=True):
    
        if wait_period > 3600: # Seconds
            print >> sys.stderr, 'Too many retries. Quitting.'
            raise e
    
        # See https://dev.twitter.com/docs/error-codes-responses for common codes
    
        if e.e.code == 401:
            print >> sys.stderr, 'Encountered 401 Error (Not Authorized)'
            return None
        elif e.e.code == 404:
            print >> sys.stderr, 'Encountered 404 Error (Not Found)'
            return None
        elif e.e.code == 429: 
            print >> sys.stderr, 'Encountered 429 Error (Rate Limit Exceeded)'
            if sleep_when_rate_limited:
                print >> sys.stderr, "Retrying in 15 minutes...ZzZ..."
                sys.stderr.flush()
                time.sleep(60*15 + 5)
                print >> sys.stderr, '...ZzZ...Awake now and trying again.'
                return 2
            else:
                raise e # Caller must handle the rate limiting issue
        elif e.e.code in (500, 502, 503, 504):
            print >> sys.stderr, 'Encountered %i Error. Retrying in %i seconds' % \
                (e.e.code, wait_period)
            time.sleep(wait_period)
            wait_period *= 1.5
            return wait_period
        else:
            raise e

    # End of nested helper function
    
    wait_period = 2 
    error_count = 0 

    while True:
        try:
            return twitter_api_func(*args, **kw)
        except twitter.api.TwitterHTTPError, e:
            error_count = 0 
            wait_period = handle_twitter_http_error(e, wait_period)
            if wait_period is None:
                return
        except URLError, e:
            error_count += 1
            print >> sys.stderr, "URLError encountered. Continuing."
            if error_count > max_errors:
                print >> sys.stderr, "Too many consecutive errors...bailing out."
                raise
        except BadStatusLine, e:
            error_count += 1
            print >> sys.stderr, "BadStatusLine encountered. Continuing."
            if error_count > max_errors:
                print >> sys.stderr, "Too many consecutive errors...bailing out."
                raise

# Sample usage

twitter_api = oauth_login()

# See https://dev.twitter.com/docs/api/1.1/get/users/lookup for 
# twitter_api.users.lookup

response = make_twitter_request(twitter_api.users.lookup, 
                                screen_name="PGi")

print json.dumps(response, indent=1)
# Out:
# [
#  {
#   "follow_request_sent": false,
#   "profile_use_background_image": true,
#   "default_profile_image": false,
#   "id": 74460479,
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/492013067790585856/B_GB2FIR.jpeg",
#   "verified": true,
#   "profile_text_color": "07222E",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000726272110/01b2e7e8e0c9f7f08d34afd5921a11bb_normal.png",
#   "profile_sidebar_fill_color": "F0F0F0",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "http://t.co/kl0kp75kOG",
#       "indices": [
#        0,
#        22
#       ],
#       "expanded_url": "http://www.pgi.com",
#       "display_url": "pgi.com"
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "followers_count": 4582,
#   "profile_sidebar_border_color": "FFFFFF",
#   "id_str": "74460479",
#   "profile_background_color": "FFFFFF",
#   "listed_count": 143,
#   "status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "#iMeet/#GlobalMeet users: Share your productivity tips, win a prize bundle! iMeet: http://t.co/uWgdT8Tewq GlobalMeet: http://t.co/MKjJWV2weh",
#    "in_reply_to_status_id": null,
#    "id": 495358548503973889,
#    "favorite_count": 1,
#    "source": "<a href=\"http://www.hootsuite.com\" rel=\"nofollow\">Hootsuite</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [],
#     "hashtags": [
#      {
#       "indices": [
#        0,
#        6
#       ],
#       "text": "iMeet"
#      },
#      {
#       "indices": [
#        7,
#        18
#       ],
#       "text": "GlobalMeet"
#      }
#     ],
#     "urls": [
#      {
#       "url": "http://t.co/uWgdT8Tewq",
#       "indices": [
#        83,
#        105
#       ],
#       "expanded_url": "http://bit.ly/iMCSummer",
#       "display_url": "bit.ly/iMCSummer"
#      },
#      {
#       "url": "http://t.co/MKjJWV2weh",
#       "indices": [
#        118,
#        140
#       ],
#       "expanded_url": "http://bit.ly/GMCSmr",
#       "display_url": "bit.ly/GMCSmr"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "id_str": "495358548503973889",
#    "retweet_count": 1,
#    "in_reply_to_user_id": null,
#    "favorited": false,
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Sat Aug 02 00:00:55 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null
#   },
#   "is_translation_enabled": false,
#   "utc_offset": -14400,
#   "statuses_count": 15948,
#   "description": "PGi provides online meeting and collaboration solutions to the world via video and web conferencing products iMeet and GlobalMeet. Questions? Let us know @PGi.",
#   "friends_count": 2622,
#   "location": "Atlanta, GA",
#   "profile_link_color": "919191",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/378800000726272110/01b2e7e8e0c9f7f08d34afd5921a11bb_normal.png",
#   "following": true,
#   "geo_enabled": false,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/74460479/1401896707",
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/492013067790585856/B_GB2FIR.jpeg",
#   "screen_name": "PGi",
#   "lang": "en",
#   "profile_background_tile": true,
#   "favourites_count": 1627,
#   "name": "PGi",
#   "notifications": false,
#   "url": "http://t.co/kl0kp75kOG",
#   "created_at": "Tue Sep 15 14:29:54 +0000 2009",
#   "contributors_enabled": false,
#   "time_zone": "Eastern Time (US & Canada)",
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
#  }
# ]

# %%
##Searching Twitter

def twitter_search(twitter_api, q, max_results=200, **kw):

    # See https://dev.twitter.com/docs/api/1.1/get/search/tweets and 
    # https://dev.twitter.com/docs/using-search for details on advanced 
    # search criteria that may be useful for keyword arguments
    
    # See https://dev.twitter.com/docs/api/1.1/get/search/tweets    
    search_results = twitter_api.search.tweets(q=q, count=100, **kw)
    
    statuses = search_results['statuses']
    
    # Iterate through batches of results by following the cursor until we
    # reach the desired number of results, keeping in mind that OAuth users
    # can "only" make 180 search queries per 15-minute interval. See
    # https://dev.twitter.com/docs/rate-limiting/1.1/limits
    # for details. A reasonable number of results is ~1000, although
    # that number of results may not exist for all queries.
    
    # Enforce a reasonable limit
    max_results = min(1000, max_results)
    
    for _ in range(10): # 10*100 = 1000
        try:
            next_results = search_results['search_metadata']['next_results']
        except KeyError, e: # No more results when next_results doesn't exist
            break
            
        # Create a dictionary from next_results, which has the following form:
        # ?max_id=313519052523986943&q=NCAA&include_entities=1
        kwargs = dict([ kv.split('=') 
                        for kv in next_results[1:].split("&") ])
        
        search_results = twitter_api.search.tweets(**kwargs)
        statuses += search_results['statuses']
        
        if len(statuses) > max_results: 
            break
            
    return statuses

# Sample usage

twitter_api = oauth_login()

q = "PGi"
results = twitter_search(twitter_api, q, max_results=10)
        
# Show one sample search result by slicing the list...
print json.dumps(results[0], indent=1)
# Out:
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "@_Veren23 yaaa:/ jm brpa so mo pgi?",
#  "in_reply_to_status_id": 495481238400942080,
#  "id": 495482537070698496,
#  "favorite_count": 0,
#  "source": "<a href=\"http://blackberry.com/twitter\" rel=\"nofollow\">Twitter for BlackBerry\u00ae</a>",
#  "retweeted": false,
#  "coordinates": null,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [
#    {
#     "id": 610857991,
#     "indices": [
#      0,
#      9
#     ],
#     "id_str": "610857991",
#     "screen_name": "_Veren23",
#     "name": "vhe"
#    }
#   ],
#   "hashtags": [],
#   "urls": []
#  },
#  "in_reply_to_screen_name": "_Veren23",
#  "in_reply_to_user_id": 610857991,
#  "retweet_count": 0,
#  "id_str": "495482537070698496",
#  "favorited": false,
#  "user": {
#   "follow_request_sent": false,
#   "profile_use_background_image": true,
#   "default_profile_image": false,
#   "id": 1361857363,
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/378800000181340098/DdMgaxKO.jpeg",
#   "verified": false,
#   "profile_text_color": "333333",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/495232543147298816/Igj6xwpl_normal.jpeg",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "followers_count": 320,
#   "profile_sidebar_border_color": "000000",
#   "id_str": "1361857363",
#   "profile_background_color": "F01313",
#   "listed_count": 0,
#   "is_translation_enabled": false,
#   "utc_offset": null,
#   "statuses_count": 22668,
#   "description": "Andre J Pangkong\u2665",
#   "friends_count": 164,
#   "location": "",
#   "profile_link_color": "F50E1A",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/495232543147298816/Igj6xwpl_normal.jpeg",
#   "following": false,
#   "geo_enabled": true,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/1361857363/1406908214",
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/378800000181340098/DdMgaxKO.jpeg",
#   "screen_name": "gloriatamon",
#   "lang": "en",
#   "profile_background_tile": true,
#   "favourites_count": 80,
#   "name": "gloriatamon",
#   "notifications": false,
#   "url": null,
#   "created_at": "Thu Apr 18 12:49:46 +0000 2013",
#   "contributors_enabled": false,
#   "time_zone": null,
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
#  },
#  "geo": null,
#  "in_reply_to_user_id_str": "610857991",
#  "lang": "in",
#  "created_at": "Sat Aug 02 08:13:37 +0000 2014",
#  "in_reply_to_status_id_str": "495481238400942080",
#  "place": null,
#  "metadata": {
#   "iso_language_code": "in",
#   "result_type": "recent"
#  }
# }

# %%
##Accessing the data in the tweets.

import json
def extract_tweet_entities(statuses):
    
    # See https://dev.twitter.com/docs/tweet-entities for more details on tweet
    # entities

    if len(statuses) == 0:
        return [], [], [], [], []
    
    screen_names = [ user_mention['screen_name'] 
                         for status in statuses
                            for user_mention in status['entities']['user_mentions'] ]
    
    hashtags = [ hashtag['text'] 
                     for status in statuses 
                        for hashtag in status['entities']['hashtags'] ]

    urls = [ url['expanded_url'] 
                     for status in statuses 
                        for url in status['entities']['urls'] ]
    
    symbols = [ symbol['text']
                   for status in statuses
                       for symbol in status['entities']['symbols'] ]
               
    # In some circumstances (such as search results), the media entity
    # may not appear
    if status['entities'].has_key('media'): 
        media = [ media['url'] 
                         for status in statuses  
                            for media in status['entities']['media'] ]
    else:
        media = []

    return screen_names, hashtags, urls, media, symbols

# Sample usage

q = '@PGi'

statuses = twitter_search(twitter_api, q)

screen_names, hashtags, urls, media, symbols = extract_tweet_entities(statuses)
    
# Explore the first five items for each...

print json.dumps(screen_names[0:5], indent=1) 
print json.dumps(hashtags[0:5], indent=1)
print json.dumps(urls[0:5], indent=1)
print json.dumps(media[0:5], indent=1)
print json.dumps(symbols[0:5], indent=1)
# Out:
# [
#  "COJsportshop",
#  "PGi",
#  "PGi",
#  "PGi",
#  "PGi"
# ]
# [
#  "GlobalMeet",
#  "iMeet",
#  "GlobalMeet",
#  "worklife",
#  "internetofthings"
# ]
# [
#  "http://bit.ly/iMCSummer",
#  "http://bit.ly/GMCSmr",
#  "http://bit.ly/1k80XUd",
#  "http://bit.ly/1k80XUd",
#  "http://bit.ly/futureofbizcollab"
# ]
# []
# []

# %%
# XXX: Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.

q = '#PGi' 

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print "Length of statuses", len(statuses)
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError, e: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print json.dumps(statuses[0], indent=1)
# Out:
# Length of statuses 100
# Length of statuses
#  100
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "RT @bobproctorLIVE: If you can dream it up - you can make it a reality. If it can be real in your mind - it can come to life. #BobProctor #\u2026",
#  "in_reply_to_status_id": null,
#  "id": 495471240035831809,
#  "favorite_count": 0,
#  "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#  "retweeted": false,
#  "coordinates": null,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [
#    {
#     "id": 22549642,
#     "indices": [
#      3,
#      18
#     ],
#     "id_str": "22549642",
#     "screen_name": "bobproctorLIVE",
#     "name": "Bob Proctor"
#    }
#   ],
#   "hashtags": [
#    {
#     "indices": [
#      126,
#      137
#     ],
#     "text": "BobProctor"
#    },
#    {
#     "indices": [
#      139,
#      140
#     ],
#     "text": "PGI"
#    }
#   ],
#   "urls": []
#  },
#  "in_reply_to_screen_name": null,
#  "in_reply_to_user_id": null,
#  "retweet_count": 84,
#  "id_str": "495471240035831809",
#  "favorited": false,
#  "retweeted_status": {
#   "contributors": null,
#   "truncated": false,
#   "text": "If you can dream it up - you can make it a reality. If it can be real in your mind - it can come to life. #BobProctor #PGI",
#   "in_reply_to_status_id": null,
#   "id": 494967519170416640,
#   "favorite_count": 90,
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       106,
#       117
#      ],
#      "text": "BobProctor"
#     },
#     {
#      "indices": [
#       118,
#       122
#      ],
#      "text": "PGI"
#     }
#    ],
#    "urls": []
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 84,
#   "id_str": "494967519170416640",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 22549642,
#    "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/378800000075538118/70d43918f7b091091f03a3e28a909b8a.png",
#    "verified": false,
#    "profile_text_color": "000000",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000464769395/1bfe4f3a7f0a260946164cf88cf76398_normal.jpeg",
#    "profile_sidebar_fill_color": "000000",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/7Uzg5aKoAZ",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://proctorgallagherinstitute.com",
#        "display_url": "proctorgallagherinstitute.com"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 61717,
#    "profile_sidebar_border_color": "FFFFFF",
#    "id_str": "22549642",
#    "profile_background_color": "FFFFFF",
#    "listed_count": 825,
#    "is_translation_enabled": false,
#    "utc_offset": -25200,
#    "statuses_count": 3073,
#    "description": "Official Bob Proctor Twitter \r\n| Expert in LOA, Human Potential and the Mind | Best Selling Author | Professional Speaker and Coach | #BobProctorChat",
#    "friends_count": 163,
#    "location": "",
#    "profile_link_color": "01A58D",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/378800000464769395/1bfe4f3a7f0a260946164cf88cf76398_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/22549642/1372077764",
#    "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/378800000075538118/70d43918f7b091091f03a3e28a909b8a.png",
#    "screen_name": "bobproctorLIVE",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 3,
#    "name": "Bob Proctor",
#    "notifications": false,
#    "url": "http://t.co/7Uzg5aKoAZ",
#    "created_at": "Mon Mar 02 23:04:05 +0000 2009",
#    "contributors_enabled": false,
#    "time_zone": "Pacific Time (US & Canada)",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "lang": "en",
#   "created_at": "Thu Jul 31 22:07:07 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  "user": {
#   "follow_request_sent": false,
#   "profile_use_background_image": true,
#   "default_profile_image": false,
#   "id": 141166070,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme3/bg.gif",
#   "verified": false,
#   "profile_text_color": "634047",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/439368280189329408/qDiUDwec_normal.jpeg",
#   "profile_sidebar_fill_color": "E3E2DE",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "http://t.co/PDdWNgNXfx",
#       "indices": [
#        0,
#        22
#       ],
#       "expanded_url": "http://about.me/haq.sanaul",
#       "display_url": "about.me/haq.sanaul"
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "followers_count": 331,
#   "profile_sidebar_border_color": "D3D2CF",
#   "id_str": "141166070",
#   "profile_background_color": "EDECE9",
#   "listed_count": 10,
#   "is_translation_enabled": false,
#   "utc_offset": 21600,
#   "statuses_count": 4059,
#   "description": "",
#   "friends_count": 292,
#   "location": "Dhaka, Bangladesh",
#   "profile_link_color": "088253",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/439368280189329408/qDiUDwec_normal.jpeg",
#   "following": false,
#   "geo_enabled": true,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/141166070/1398263063",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme3/bg.gif",
#   "screen_name": "haq68",
#   "lang": "en",
#   "profile_background_tile": false,
#   "favourites_count": 4069,
#   "name": "Md Sanaul Haq",
#   "notifications": false,
#   "url": "http://t.co/PDdWNgNXfx",
#   "created_at": "Fri May 07 10:18:24 +0000 2010",
#   "contributors_enabled": false,
#   "time_zone": "Dhaka",
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
#  },
#  "geo": null,
#  "in_reply_to_user_id_str": null,
#  "lang": "en",
#  "created_at": "Sat Aug 02 07:28:43 +0000 2014",
#  "in_reply_to_status_id_str": null,
#  "place": null,
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  }
# }

# %%
#Accessing the followers

from functools import partial
from sys import maxint

def get_friends_followers_ids(twitter_api, screen_name=None, user_id=None,
                              friends_limit=maxint, followers_limit=maxint):
    
    # Must have either screen_name or user_id (logical xor)
    assert (screen_name != None) != (user_id != None), \
    "Must have screen_name or user_id, but not both"
    
    # See https://dev.twitter.com/docs/api/1.1/get/friends/ids and
    # https://dev.twitter.com/docs/api/1.1/get/followers/ids for details
    # on API parameters
    
    get_friends_ids = partial(make_twitter_request, twitter_api.friends.ids, 
                              count=5000)
    get_followers_ids = partial(make_twitter_request, twitter_api.followers.ids, 
                                count=5000)

    friends_ids, followers_ids = [], []
    
    for twitter_api_func, limit, ids, label in [
                    [get_friends_ids, friends_limit, friends_ids, "friends"], 
                    [get_followers_ids, followers_limit, followers_ids, "followers"]
                ]:
        
        if limit == 0: continue
        
        cursor = -1
        while cursor != 0:
        
            # Use make_twitter_request via the partially bound callable...
            if screen_name: 
                response = twitter_api_func(screen_name=screen_name, cursor=cursor)
            else: # user_id
                response = twitter_api_func(user_id=user_id, cursor=cursor)

            if response is not None:
                ids += response['ids']
                cursor = response['next_cursor']
        
            print >> sys.stderr, 'Fetched {0} total {1} ids for {2}'.format(len(ids), 
                                                    label, (user_id or screen_name))
        
            # XXX: You may want to store data during each iteration to provide an 
            # an additional layer of protection from exceptional circumstances
        
            if len(ids) >= limit or response is None:
                break

    # Do something useful with the IDs, like store them to disk...
    return friends_ids[:friends_limit], followers_ids[:followers_limit]

# Sample usage

twitter_api = oauth_login()

friends_ids, followers_ids = get_friends_followers_ids(twitter_api, 
                                                       screen_name="PGi", 
                                                       friends_limit=10, 
                                                       followers_limit=10)

print friends_ids
print followers_ids
# Out:
# Fetched 2622 total friends ids for PGi
# Fetched 4582 total followers ids for PGi
# [20920486, 1499084576, 14363427, 384955112, 57682960, 16318230, 392253657, 52256343, 2648862163L, 85619135]
# [306930864, 92976256, 44172348, 1438943570, 2693619804L, 1390285436, 16906942, 1479947258, 2695779230L, 392268718]

# %%
#Accessing the timeline

def harvest_user_timeline(twitter_api, screen_name=None, user_id=None, max_results=1000):
     
    assert (screen_name != None) != (user_id != None), \
    "Must have screen_name or user_id, but not both"    
    
    kw = {  # Keyword args for the Twitter API call
        'count': 200,
        'trim_user': 'true',
        'include_rts' : 'true',
        'since_id' : 1
        }
    
    if screen_name:
        kw['screen_name'] = screen_name
    else:
        kw['user_id'] = user_id
        
    max_pages = 16
    results = []
    
    tweets = make_twitter_request(twitter_api.statuses.user_timeline, **kw)
    
    if tweets is None: # 401 (Not Authorized) - Need to bail out on loop entry
        tweets = []
        
    results += tweets
    
    print >> sys.stderr, 'Fetched %i tweets' % len(tweets)
    
    page_num = 1
    
    # Many Twitter accounts have fewer than 200 tweets so you don't want to enter
    # the loop and waste a precious request if max_results = 200.
    
    # Note: Analogous optimizations could be applied inside the loop to try and 
    # save requests. e.g. Don't make a third request if you have 287 tweets out of 
    # a possible 400 tweets after your second request. Twitter does do some 
    # post-filtering on censored and deleted tweets out of batches of 'count', though,
    # so you can't strictly check for the number of results being 200. You might get
    # back 198, for example, and still have many more tweets to go. If you have the
    # total number of tweets for an account (by GET /users/lookup/), then you could 
    # simply use this value as a guide.
    
    if max_results == kw['count']:
        page_num = max_pages # Prevent loop entry
    
    while page_num < max_pages and len(tweets) > 0 and len(results) < max_results:
    
        # Necessary for traversing the timeline in Twitter's v1.1 API:
        # get the next query's max-id parameter to pass in.
        # See https://dev.twitter.com/docs/working-with-timelines.
        kw['max_id'] = min([ tweet['id'] for tweet in tweets]) - 1 
    
        tweets = make_twitter_request(twitter_api.statuses.user_timeline, **kw)
        results += tweets

        print >> sys.stderr, 'Fetched %i tweets' % (len(tweets),)
    
        page_num += 1
        
    print >> sys.stderr, 'Done fetching tweets'

    return results[:max_results]
    
# Sample usage

twitter_api = oauth_login()
tweets = harvest_user_timeline(twitter_api, screen_name="PGi", \
                               max_results=200)

# Save to MongoDB with save_to_mongo or a local file with save_json...
# Out:
# Fetched 200 tweets
# Done fetching tweets

# %%
tweets
# Out:
# [{u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Aug 02 00:00:55 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [0, 6], u'text': u'iMeet'},
#     {u'indices': [7, 18], u'text': u'GlobalMeet'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/iMCSummer',
#      u'expanded_url': u'http://bit.ly/iMCSummer',
#      u'indices': [83, 105],
#      u'url': u'http://t.co/uWgdT8Tewq'},
#     {u'display_url': u'bit.ly/GMCSmr',
#      u'expanded_url': u'http://bit.ly/GMCSmr',
#      u'indices': [118, 140],
#      u'url': u'http://t.co/MKjJWV2weh'}],
#    u'user_mentions': []},
#   u'favorite_count': 1,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 495358548503973889L,
#   u'id_str': u'495358548503973889',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 1,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   u'text': u'#iMeet/#GlobalMeet users: Share your productivity tips, win a prize bundle! iMeet: http://t.co/uWgdT8Tewq GlobalMeet: http://t.co/MKjJWV2weh',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Fri Aug 01 23:00:55 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [101, 110], u'text': u'worklife'},
#     {u'indices': [111, 128], u'text': u'internetofthings'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/1k80XUd',
#      u'expanded_url': u'http://bit.ly/1k80XUd',
#      u'indices': [60, 82],
#      u'url': u'http://t.co/7WOqMkgLtK'}],
#    u'user_mentions': [{u'id': 2648862163L,
#      u'id_str': u'2648862163',
#      u'indices': [86, 100],
#      u'name': u'Ashley Speagle',
#      u'screen_name': u'AshleySpeagle'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 495343445264048129L,
#   u'id_str': u'495343445264048129',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 2,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   u'text': u'Is technology really the big bad wolf to work-life balance? http://t.co/7WOqMkgLtK by @AshleySpeagle #worklife #internetofthings',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Fri Aug 01 22:01:41 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [2, 6], u'text': u'B2B'},
#     {u'indices': [34, 51], u'text': u'contentmarketing'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/1qIUlP7',
#      u'expanded_url': u'http://bit.ly/1qIUlP7',
#      u'indices': [53, 75],
#      u'url': u'http://t.co/cHmQyirrfB'}],
#    u'user_mentions': [{u'id': 46768880,
#      u'id_str': u'46768880',
#      u'indices': [80, 88],
#      u'name': u'CMO.com',
#      u'screen_name': u'CMO_com'},
#     {u'id': 506287341,
#      u'id_str': u'506287341',
#      u'indices': [89, 101],
#      u'name': u'Giselle Abramovich',
#      u'screen_name': u'GAbramovich'},
#     {u'id': 16500047,
#      u'id_str': u'16500047',
#      u'indices': [102, 115],
#      u'name': u'Jeff Perkins',
#      u'screen_name': u'jeffperkins8'},
#     {u'id': 76117579,
#      u'id_str': u'76117579',
#      u'indices': [119, 123],
#      u'name': u'SAP',
#      u'screen_name': u'SAP'},
#     {u'id': 42712551,
#      u'id_str': u'42712551',
#      u'indices': [124, 140],
#      u'name': u'American Express',
#      u'screen_name': u'AmericanExpress'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 
}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'slidesha.re/1rTo7Pb',
#      u'expanded_url': u'http://slidesha.re/1rTo7Pb',
#      u'indices': [47, 69],
#      u'url': u'http://t.co/teIkpxeVmj'}],
#    u'user_mentions': [{u'id': 9676152,
#      u'id_str': u'9676152',
#      u'indices': [73, 84],
#      u'name': u'SlideShare',
#      u'screen_name': u'SlideShare'},
#     {u'id': 352538333,
#      u'id_str': u'352538333',
#      u'indices': [85, 95],
#      u'name': u'Haiku Deck',
#      u'screen_name': u'HaikuDeck'},
#     {u'id': 123559513,
#      u'id_str': u'123559513',
#      u'indices': [96, 102],
#      u'name': u'Any.DO',
#      u'screen_name': u'AnyDO'},
#     {u'id': 13837292,
#      u'id_str': u'13837292',
#      u'indices': [103, 112],
#      u'name': u'evernote',
#      u'screen_name': u'evernote'},
#     {u'id': 14749606,
#      u'id_str': u'14749606',
#      u'indices': [113, 121],
#      u'name': u'Dropbox',
#      u'screen_name': u'Dropbox'},
#     {u'id': 27530178,
#      u'id_str': u'27530178',
#      u'indices': [122, 129],
#      u'name': u'Pocket',
#      u'screen_name': u'Pocket'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 495268725453754369L,
#   u'id_str': u'495268725453754369',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 1,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   u'text': u'5 productivity apps to boost your work skills: http://t.co/teIkpxeVmj w/ @SlideShare @HaikuDeck @AnyDO @Evernote @Dropbox @Pocket #Agenday',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Fri Aug 01 17:48:16 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [22, 34], u'text': u'meetingfail'}],
#    u'media': [{u'display_url': u'pic.twitter.com/OvKPRW1zym',
#      u'expanded_url': u'http://twitter.com/PGi/status/495264765317357569/photo/1',
#      u'id': 495264764214267905L,
#      u'id_str': u'495264764214267905',
#      u'indices': [35, 57],
#      u'media_url': u'http://pbs.twimg.com/media/Bt-IrdTCUAE66Vv.png',
#      u'media_url_https': u'https://pbs.twimg.com/media/Bt-IrdTCUAE66Vv.png',
#      u'sizes': {u'large': {u'h': 237, u'resize': u'fit', u'w': 425},
#       u'medium': {u'h': 237, u'resize': u'fit', u'w': 425},
#       u'small': {u'h': 189, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/OvKPRW1zym'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': []},
#   u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/OvKPRW1zym',
#      u'expanded_url': u'http://twitter.com/PGi/status/495264765317357569/photo/1',
#      u'id': 495264764214267905L,
#      u'id_str': u'495264764214267905',
#      u'indices': [35, 57],
#      u'media_url': u'http://pbs.twimg.com/media/Bt-IrdTCUAE66Vv.png',
#      u'media_url_https': u'https://pbs.twimg.com/media/Bt-IrdTCUAE66Vv.png',
#      u'sizes': {u'large': {u'h': 237, u'resize': u'fit', u'w': 425},
#       u'medium': {u'h': 237, u'resize': u'fit', u'w': 425},
#       u'small': {u'h': 189, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/OvKPRW1zym'}]},
#   u'favorite_count': 1,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 495264765317357569L,
#   u'id_str': u'495264765317357569',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 1,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   u'text': u'Can anyone relate? ;) #meetingfail http://t.co/OvKPRW1zym',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Fri Aug 01 17:44:04 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [0, 12], u'text': u'Millennials'},
#     {u'indices': [22, 34], u'text': u'careerguide'}],
#    u'media': [{u'display_url': u'pic.twitter.com/swcwkyZWiB',
#      u'expanded_url': u'http://twitter.com/PGi/status/495263709829148672/photo/1',
#      u'id': 495263708386308097L,
#      u'id_str': u'495263708386308097',
#      u'indices': [123, 145],
#      u'media_url': u'http://pbs.twimg.com/media/Bt-HuACCMAENwth.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/Bt-HuACCMAENwth.jpg',
#      u'sizes': {u'large': {u'h': 1024, u'resize': u'fit', u'w': 1024},
#       u'medium': {u'h': 600, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 340, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/swcwkyZWiB'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/1tgei0u',
#      u'expanded_url': u'http://bit.ly/1tgei0u',
#      u'indices': [100, 122],
#      u'url': u'http://t.co/n8pPM2lTpI'}],
#    u'user_mentions': []},
#   u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/swcwkyZWiB',
#      u'expanded_url': u'http://twitter.com/PGi/status/495263709829148672/photo/1',
#      u'id': 495263708386308097L,
#      u'id_str': u'495263708386308097',
#      u'indices': [123, 145],
#      u'media_url': u'http://pbs.twimg.com/media/Bt-HuACCMAENwth.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/Bt-HuACCMAENwth.jpg',
#      u'sizes': {u'large': {u'h': 1024, u'resize': u'fit', u'w': 1024},
#       u'medium': {u'h': 600, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 340, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/swcwkyZWiB'}]},
#   u'favorite_count': 3,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 495263709829148672L,
#   u'id_str': u'495263709829148672',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   u'text': u'#Millennials: Get our #careerguide &amp; learn how to find, get &amp; keep a job you actually want! http://t.co/n8pPM2lTpI http://t.co/swcwkyZWiB',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Fri Aug 01 17:24:43 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [47, 56], u'text': u'flexible'},
#     {u'indices': [128, 140], u'text': u'telecommute'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/1nXTKqI',
#      u'expanded_url': u'http://bit.ly/1nXTKqI',
#      u'indices': [74, 96],
#      u'url': u'http://t.co/SjVgyjtKxZ'}],
#    u'user_mentions': [{u'id': 1499084576,
#      u'id_str': u'1499084576',
#      u'indices': [101, 117],
#      u'name': u'1MforWorkFlexibility',
#      u'screen_name': u'workflexibility'},
#     {u'id': 52256343,
#      u'id_str': u'52256343',
#      u'indices': [118, 127],
#      u'name': u'Lorna Love',
#      u'screen_name': u'LornaLuv'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 495258840649465856L,
#   u'id_str': u'495258840649465856',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 1,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   u'text': u'Do you have the personality to be a successful #flexible worker? Find out http://t.co/SjVgyjtKxZ via @workflexibility @lornaluv #telecommute',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Fri Aug 01 16:06:31 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [0, 6], u'text': u'iMeet'},
#     {u'indices': [7, 18], u'text': u'GlobalMeet'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/iMCSummer',
#      u'expanded_url': u'http://bit.ly/iMCSummer',
#      u'indices': [83, 105],
#      u'url': u'http://t.co/uWgdT8Tewq'},
#     {u'display_url': u'bit.ly/GMCSmr',
#      u'expanded_url': u'http://bit.ly/GMCSmr',
#      u'indices': [118, 140],
#      u'url': u'http://t.co/MKjJWV2weh'}],
#    u'user_mentions': []},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 495239158202634241L,
#   u'id_str': u'495239158202634241',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   u'text': u'#iMeet/#GlobalMeet users: Share your productivity tips, win a prize bundle! iMeet: http://t.co/uWgdT8Tewq GlobalMeet: http://t.co/MKjJWV2weh',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Fri Aug 01 15:03:07 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [0, 3], u'text': u'HR'},
#     {u'indices': [12, 24], u'text': u'Millennials'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/1zkg6pK',
#      u'expanded_url': u'http://bit.ly/1zkg6pK',
#      u'indices': [93, 115],
#      u'url': u'http://t.co/qE1eguv166'},
#     {u'display_url': u'ow.ly/i/6cDaI',
#      u'expanded_url': u'http://ow.ly/i/6cDaI',
#      u'indices': [117, 139],
#      u'url': u'http://t.co/ckZplGDdS7'}],
#    u'user_mentions': []},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 495223204558819328L,
#   u'id_str': u'495223204558819328',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   u'text': u'#HR: 60% of #Millennials leave their job w/in 3yrs. Why in our free Millennials Field Guide: http://t.co/qE1eguv166  http://t.co/ckZplGDdS7',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Fri Aug 01 14:01:31 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [0, 8], u'text': u'Atlanta'},
#     {u'indices': [35, 38], u'text': u'IT'},
#     {u'indices': [91, 95], u'text': u'ATL'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u
}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/1k80XUd',
#      u'expanded_url': u'http://bit.ly/1k80XUd',
#      u'indices': [60, 82],
#      u'url': u'http://t.co/7WOqMkgLtK'}],
#    u'user_mentions': [{u'id': 2648862163L,
#      u'id_str': u'2648862163',
#      u'indices': [86, 100],
#      u'name': u'Ashley Speagle',
#      u'screen_name': u'AshleySpeagle'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 495026246582288384L,
#   u'id_str': u'495026246582288384',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 2,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   u'text': u'Is technology really the big bad wolf to work-life balance? http://t.co/7WOqMkgLtK by @AshleySpeagle #worklife #internetofthings',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Fri Aug 01 01:01:12 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [2, 6], u'text': u'B2B'},
#     {u'indices': [34, 51], u'text': u'contentmarketing'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/1qIUlP7',
#      u'expanded_url': u'http://bit.ly/1qIUlP7',
#      u'indices': [53, 75],
#      u'url': u'http://t.co/C7BR6vbixo'}],
#    u'user_mentions': [{u'id': 46768880,
#      u'id_str': u'46768880',
#      u'indices': [80, 88],
#      u'name': u'CMO.com',
#      u'screen_name': u'CMO_com'},
#     {u'id': 506287341,
#      u'id_str': u'506287341',
#      u'indices': [89, 101],
#      u'name': u'Giselle Abramovich',
#      u'screen_name': u'GAbramovich'},
#     {u'id': 16500047,
#      u'id_str': u'16500047',
#      u'indices': [102, 115],
#      u'name': u'Jeff Perkins',
#      u'screen_name': u'jeffperkins8'},
#     {u'id': 76117579,
#      u'id_str': u'76117579',
#      u'indices': [119, 123],
#      u'name': u'SAP',
#      u'screen_name': u'SAP'},
#     {u'id': 42712551,
#      u'id_str': u'42712551',
#      u'indices': [124, 140],
#      u'name': u'American Express',
#      u'screen_name': u'AmericanExpress'}]},
#   u'favorite_count': 1,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 495011329586233344L,
#   u'id_str': u'495011329586233344',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   u'text': u'3 #B2B brands in control of their #contentmarketing: http://t.co/C7BR6vbixo via @CMO_com @gabramovich @jeffperkins8 w/ @SAP @americanexpress',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Fri Aug 01 00:43:24 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [47, 56], u'text': u'flexible'},
#     {u'indices': [128, 140], u'text': u'telecommute'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/1nXTKqI',
#      u'expanded_url': u'http://bit.ly/1nXTKqI',
#      u'indices': [74, 96],
#      u'url': u'http://t.co/DCs3y6zXTT'}],
#    u'user_mentions': [{u'id': 1499084576,
#      u'id_str': u'1499084576',
#      u'indices': [101, 117],
#      u'name': u'1MforWorkFlexibility',
#      u'screen_name': u'workflexibility'},
#     {u'id': 52256343,
#      u'id_str': u'52256343',
#      u'indices': [118, 127],
#      u'name': u'Lorna Love',
#      u'screen_name': u'LornaLuv'}]},
#   u'favorite_count': 1,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 495006848819269632L,
#   u'id_str': u'495006848819269632',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 1,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   u'text': u'Do you have the personality to be a successful #flexible worker? Find out http://t.co/DCs3y6zXTT via @workflexibility @lornaluv #telecommute',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Fri Aug 01 00:00:57 +0000 2014',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/1poGmu3',
#      u'expanded_url': u'http://bit.ly/1poGmu3',
#      u'indices': [119, 141],
#      u'url': u'http://t.co/UWxAzPbFlZ'}],
#    u'user_mentions': [{u'id': 17867641,
#      u'id_str': u'17867641',
#      u'indices': [58, 66],
#      u'name': u"Sean O'Brien",
#      u'screen_name': u'seanobr'},
#     {u'id': 2735591,
#      u'id_str': u'2735591',
#      u'indices': [76, 88],
#      u'name': u'Fast Company',
#      u'screen_name': u'FastCompany'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 494996167646642176L,
#   u'id_str': u'494996167646642176',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   u'text': u'Find the sweet spot between bored &amp; stressed. Our own @seanobr spoke w/ @FastCompany about 7 time-management tips: http://t.co/UWxAzPbFlZ',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Jul 31 23:01:46 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [130, 138], u'text': u'Agenday'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'slidesha.re/1rTo7Pb',
#      u'expanded_url': u'http://slidesha.re/1rTo7Pb',
#      u'indices': [47, 69],
#      u'url': u'http://t.co/teIkpxeVmj'}],
#    u'user_mentions': [{u'id': 9676152,
#      u'id_str': u'9676152',
#      u'indices': [73, 84],
#      u'name': u'SlideShare',
#      u'screen_name': u'SlideShare'},
#     {u'id': 352538333,
#      u'id_str': u'352538333',
#      u'indices': [85, 95],
#      u'name': u'Haiku Deck',
#      u'screen_name': u'HaikuDeck'},
#     {u'id': 123559513,
#      u'id_str': u'123559513',
#      u'indices': [96, 102],
#      u'name': u'Any.DO',
#      u'screen_name': u'AnyDO'},
#     {u'id': 13837292,
#      u'id_str': u'13837292',
#      u'indices': [103, 112],
#      u'name': u'evernote',
#      u'screen_name': u'evernote'},
#     {u'id': 14749606,
#      u'id_str': u'14749606',
#      u'indices': [113, 121],
#      u'name': u'Dropbox',
#      u'screen_name': u'Dropbox'},
#     {u'id': 27530178,
#      u'id_str': u'27530178',
#      u'indices': [122, 129],
#      u'name': u'Pocket',
#      u'screen_name': u'Pocket'}]},
#   u'favorite_count': 1,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 494981271786098688L,
#   u'id_str': u'494981271786098688',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 1,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   u'text': u'5 productivity apps to boost your work skills: http://t.co/teIkpxeVmj w/ @SlideShare @HaikuDeck @AnyDO @Evernote @Dropbox @Pocket #Agenday',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Jul 31 22:01:22 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [17, 28], u'text': u'smartphone'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/1AqD8Mg',
#      u'expanded_url': u'http://bit.ly/1AqD8Mg',
#      u'indices': [111, 133],
#      u'url': u'http://t.co/FqmC79xlU3'}],
#    u'user_mentions': [{u'id': 106335982,
#      u'id_str': u'106335982',
#      u'indices': [30, 40],
#      u'name': u'Josh Erwin',
#      u'screen_name': u'writerwin'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 494966072110755840L,
#   u'id_str': u'494966072110755840',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   u'text': u'Addicted to your #smartphone? @writerwin shares tips to quell your reliance while still keeping it accessible: http://t.co/FqmC79xlU3',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Jul 31 21:01:48 +0000 2014',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/PGiCareers',
#      u'expanded_url': u'http://bit.ly/PGiCareers',
#      u'indices': [74, 96],
#      u'url': u'http://t.co/qUPkVKEWv6'},
#     {u'display_url': u'ow.ly/i/6lR22',
#      u'expanded_url': u'http://ow.ly/i/6lR22',
#      u'indices': [109, 131],
#      u'url': u'http://t.co/LRXlAA1Wqn'}],
#    u'user_mentions': [{u'id': 211401802,
#      u'id_str': u'211401802',
#      u'indices': [100, 108],
#      u'name': u'Julie Johnson',
#      u'screen_name': u'PGiJobs'}]},
#   u'favorite_count': 1,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 494951084155473920L,
#   u'id_str': u'494951084155473920',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 1,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   u'text': u'Come join our awesome team! We have a variety of positions open. Go here: http://t.co/qUPkVKEWv6 w/ @PGiJobs http://t.co/LRXlAA1Wqn',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Jul 31 20:02:17 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [0, 11], u'text': u'GlobalMeet'},
#     {u'indices': [51, 67], u'text': u'conferencecalls'},
#     {u'indices': [76, 83], u'text': u'iPhone'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/1lEnnHA',
#      u'expanded_url': u'http://bit.ly/1lEnnHA',
#      u'indices': [110, 132],
#      u'url': u'http://t.co/iw8DOFuqrd'}],
#    u'user_mentions': []},
#   u'favorite_count': 1,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 494936102881734656L,
#   u'id_str': u'494936102881734656',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   u'text': u'#GlobalMeet makes it super easy to manage and join #conferencecalls on your #iPhone. Watch this quick how-to: http://t.co/iw8DOFuqrd',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Jul 31 20:01:18 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [0, 8], u'text': u'Atlanta'},
#     {u'indices': [35, 38], u'text': u'IT'},
#     {u'indices': [91, 95], u'text': u'ATL'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'on-ajc.com/1AEhcNN',
#      u'expanded_url': u'http://on-ajc.com/1AEhcNN',
#      u'indices': [59, 81],
#      u'url': u'http://t.co/jDpy6V00p0'}],
#    u'user_mentions': [{u'id': 4170491,
#      u'id_str': u'4170491',
#      u'indices': [86, 90],
#      u'name': u'AJC ',
#      u'screen_name': u'ajc'}]},
#   u'favorite_count': 1,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 494935859209461760L,
#   u'id_str': u'494935859209461760',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   u'text': u'#Atlanta makes the Top 10 List for #IT jobs! Check it out: http://t.co/jDpy6V00p0 via @AJC #ATL',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Jul 31 19:54:14 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [0, 6], u'text': u'iMeet'},
#     {u'indices': [7, 18], u'text': u'GlobalMeet'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/iMCSummer',
#      u'expanded_url': u'http://bit.ly/iMCSummer',
#      u'indices': [83, 105],
#      u'url': u'http://t.co/3LLpnz25w9'},
#     {u'display_url': u'bit.ly/GMCSmr',
#      u'expanded_url': u'http://bit.ly/GMCSmr',
#      u'indices': [118, 140],
#      u'url': u'http://t.co/sq4mVHtsIh'}],
#    u'user_mentions': []},
#   u'favorite_count': 2,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 494934076822781952L,
#   u'id_str': u'494934076822781952',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 1,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   u'text': u'#iMeet/#GlobalMeet users: Share your productivity tips, win a prize bundle! iMeet: http://t.co/3LLpnz25w9 GlobalMeet: http://t.co/sq4mVHtsIh',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Jul 31 19:46:01 +0000 2014',
# ...
#   u'favorite_count': 1,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 492094267566080001L,
#   u'id_str': u'492094267566080001',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 1,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   u'text': u'Need more time in your day? Increase productivity w/ our award-winning free calendar app: http://t.co/jrosf5tHpr http://t.co/CkVY5NKVhU',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Wed Jul 23 23:30:23 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [108, 111], u'text': u'IT'},
#     {u'indices': [112, 121], u'text': u'Strategy'},
#     {u'indices': [122, 126], u'text': u'CIO'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/1paOezd',
#      u'expanded_url': u'http://bit.ly/1paOezd',
#      u'indices': [85, 107],
#      u'url': u'http://t.co/6d05E7aBjD'}],
#    u'user_mentions': [{u'id': 22825992,
#      u'id_str': u'22825992',
#      u'indices': [130, 140],
#      u'name': u'FierceCIO',
#      u'screen_name': u'FierceCIO'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 492089371663679489L,
#   u'id_str': u'492089371663679489',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   u'text': u'Don\u2019t miss our next webinar on Consumerization &amp; the CIO: 7/29 at 2p ET/11am PT: http://t.co/6d05E7aBjD #IT #Strategy #CIO w/ @FierceCIO',
#   u'truncated': False,
#   u'user': {u'id': 74460479, u'id_str': u'74460479'}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Wed Jul 23 23:19:14 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [23, 36], u'text': u'productivity'},
#     {u'indices': [43, 57], u'text': u'collaboration'},
#     {u'indices': [135, 143], u'text': u'Agenday'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/